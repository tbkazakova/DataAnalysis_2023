# %% [markdown]
# # Контрольная работа

# %%
# один пункт - один балл

# %% [markdown]
# ### Питон
# Перед вами часть большого списка песен ансамбля КСП "Надежда"

# %%
# ваш код должен работать с любым словарём подобного формата

songs = {'Зеленоватые слегка': {'отрепетированность': 1,
                             'незапетость': 3,
                             'авторы': ['Б.Вахнюк']},
          'Не греет': {'отрепетированность': 5,
                      'незапетость': 2,
                      'авторы': ['М.Светлов',
                                'Ю.Визбор',
                                'С.Никитин']},
          'Снег идёт': {'отрепетированность': 5,
                       'незапетость': 4,
                       'авторы': ['Б.Пастернак',
                                 'С.Никитин']},
          'Баллада о щепке': {'отрепетированность': 4,
                            'незапетость': 4,
                            'авторы': ['Ю.Мориц',
                                      'С.Никитин']},
          'Ключ': {'отрепетированность': 3,
                   'незапетость': 3,
                   'авторы': ['Ю.Визбор']},
          'Вересковый мёд': {'отрепетированность': 0,
                           'незапетость': 5,
                           'авторы': ['Р.Стивенсон',
                                     'С.Маршака']},
          'Стать богатеем': {'отрепетированность': 4,
                           'незапетость': 1,
                           'авторы': ['Б.Окуджава']}}

# %% [markdown]
# 1. Что ансамбль может спеть на вечере песен Сергея Никитина? (у каких песен он среди авторов)
# 2. Отсортируйте по приоритетности полученный список и выведите сначала более приоритетные песни. Чем больше сумма очков за отрепетированность и незапетость, тем песня приоритетнее. Например: у песни "Зеленоватые слегка" сумма очков 5.

# %% [markdown]
# 3. Участники ансамбля не хотят петь некоторые из песен на ближайшем концерте. Выведите **множество** песен, которые хотя бы один учасник не хочет петь.

# %%
blacklist = {'Катя': {'Вересковый мёд'},
            'Алина': {'Ключ', 'Зеленоватые слегка'},
            'Лена': {'Зеленоватые слегка'},
            'Таня': {'Зеленоватые слегка'}}

# %% [markdown]
# 4. Ансамбль поёт песню только если все участники согласны. Добавьте в словарь `songs` к каждой песне информацию о желательности в фомате True/False.
#
# Так, например, должен выглядеть словарь с песней "Ключ"
# ```
# 'Ключ': {'отрепетированность': 3,
#          'незапетость': 3,
#          'авторы': ['Ю.Визбор']}
#          'желательность': False,
# ```

# %% [markdown]
# 5. Напишите функцию `pretty()`, которая принимает строку с именем и фамилией в формате И.Фамилия или И. Фамилия и при отсутствии пробела добавляет его.
#
# Примеры:
# ```
# pretty('С.Никитин')
# возвращает: 'С. Никитин'
#
# pretty('С. Никитин')
# возвращает: 'С. Никитин'
# ```

# %% [markdown]
# ### Андан
#
# 1-2. Объясните своими словами, что такое стандартное отклонение и зачем оно нужно. Можно гуглить, но цитата из википедии не подойдёт. Приведите примеры ситуаций, когда важно знать не только среднее арифметическое или медиану, но и стандартное отклонение.

# %% [markdown]
# Перед вами таблица с метаданными `meta.csv`. Это фольклорные тексты, собранные Иркутским Государственным Университетом.
#
# 3. В каком году был собран самый ранний текст? (год сбора текста - столбец `collyear`) Сколько разных жанров в этой таблице? (жанр - столбец `genre`)
#
# 4. Выведите, сколько текстов от каждого из авторов, отсортировав от большего к меньшему. (для этого сгруппируйте тексты по фамилиям авторов - столбец `surname` и отсортируйте в порядке убывания)
#
# 5. Найдите самый длинный текст (столбец `text`) и скажите, в каком он хранится файле (столбец `filename`) и кто его набрал (столбец `collector`).

# %% [markdown]
# # ДЗ11
#
# Дедлайн: 4 мая (23:59)
#
# ДЗ можно [загружать по ссылке](https://classroom.github.com/a/6lmkBGUY).
#
# Перед вами датасет Титаник. (Подробная информация о нём [по ссылке](https://www.kaggle.com/c/titanic).)

# %% [markdown]
# 1. Напишите, какого типа переменные `Pclass`, `Name`, `Sex`, `Age`, `SibSp`, `Fare`.
# Варианты ответа: числовая непрерывная, числовая дискретная, категориальная порядковая, категориальная номинальная, бинарная
#
# *👉 Тут (или внизу в виде DataFrame) будет ваш ответ 👈*

# %% [markdown]
# \+ 1 балл, если выведете ответ в виде датафрейма

# %%
# пример датафрейма
# Out:
#         column                        Type
# 0  PassengerId         числовая дискретная
# 1     Embarked  категориальная номинальная

# %% [markdown]
# *Эти действия дают нам общее представление о числовых колонках:*
#
# 2.1 Используя метод `.describe()`, выведите статистику по числовым колонкам.
#
# 2.2 Напишите, чему равно (просто напишите числа, но округлите до сотых)
# - стандартное отклонение в `Age`
# - медиана в `Fare`
# - Q3 (третий квантиль) в `SibSp`
#
# *👉 Тут будет ваш ответ 👈*

# %% [markdown]
# 3.1 Какая мода в столбце `Cabin` (в какой каюте жило больше всего человек)?
#     *(если мод несколько, укажите их через запятую)*
#
# 3.2 Сколько этих человек было?
#
# (приведите код, по которому вы это узнали)

# %% [markdown]
# *Эти действия знакомят нас с данными, показывают распределение данных по категориям:*
#
# 4.1 Сгруппируйте данные по классу, которым ехали пассажиры, (`Pclass`) и, внутри классов, по полу пассажиров (`Sex`).
#    Вы можете использовать `.value_counts()` или `.groupby()`.
#
# **Запишите здесь ваши наблюдения, кого больше, мужчин или женщин? Зависит ли это от класса?**:
#
# *👉 Тут будет ваш ответ 👈*
#
# 4.2 Как и в предыдущем пункте, сгруппируйте данные по классу, которым ехали пассажиры, (`Pclass`) и, внутри классов, по полу пассажиров (`Sex`).
#     Но теперь посчитайте, какая медиана возраста пассажиров в каждой комбинации класса и пола).
#
#     В этом пункте вам понадобится `.groupby()`, т.к. с `value_counts()` такого не посчитать.
#
# **Запишите здесь ваши наблюдения, ожидаемо ли такое распределение средних возрастов? С чем оно может быть связано?**:
#
# *👉 Тут будет ваш ответ 👈*

# %% [markdown]
# *все эти действия дополняют наши знания о пассажирах и заставляют подумать о разных факторах*
#
# 5.1 Напишите функцию с названием `classify_fare`, которая будет принимать один аргумент &mdash; цену поездки (`Fare`).
#     Функция должна выдавать словесное описание цены поездки:
#
# - `очень высокая`, если цена поездки выше 50 фунтов,
# - `высокая`, если цена поездки меньше или равна 50 фунтам, но больше 32 фунтов,
# - `выше среднего`, если цена поездки меньше или равна 32 фунтам, но больше 15 фунтов,
# - `ниже среднего`, если цена поездки меньше или равна 15 фунтам, но больше 0,
# - `бесплатно / экипаж`, если цена поездки ровно 0
#
# *Для справки: числа выбраны отчасти произвольно, отчасти по квантилям*
#
# 5.2 (+1 балл) Если мы применим функцию к каждой строке и получим для каждого пассажира одно из значений, перечисленных выше, то какого типа это будет переменная?
#
# *👉 Тут будет ваш ответ 👈*
#
# 5.3 Примените эту функцию к каждой строке.
#     Используйте на столбце `Fare` метод `.apply()`, который принимает название функции и применяет её к каждому элементу столбца.
#     Создайте столбец `fare_cat`, присвоив ему результат выполнения метода `.apply()`.

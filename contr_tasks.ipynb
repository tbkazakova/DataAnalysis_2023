# %% [markdown]
# # Контрольная работа

# %%
# общий комментарий: указывайте, к какому заданию и к какому пункту вы пишете код

# %% [markdown]
# Ссылка на сдачу: https://classroom.github.com/a/WocL1NOA

# %% [markdown]
# ## Для 1 и 3 вариантов

# %% [markdown]
# ### Фильмы
# Квентин решил понять, много ли фильмов с короткими названиями.
# Помогите ему, посчитав количество фильмов, название которых короче `7` символов.
#
# ФОРМАТ ВВОДА
#
# - На каждой строке вводится одно название фильма.
# - Гарантируется, что вводится как минимум одно название.
# - Ввод фильмов заканчивается, когда вводится строка "КОНЕЦ".
#
# ФОРМАТ ВЫВОДА
#
# Целое число — количество фильмов, у которых длина названия короче, чем 7.
#
#
# **Пример**:
#
# Ввод:
#
#     Риф
#     Бриллиантовая рука
#     Птицы
#     КОНЕЦ
#
# Результат:
#
#     2
#
# Ввод:
#
#     Острова
#     КОНЕЦ
#
# Результат:
#
#     0

# %% [markdown]
# ### Словарь
#
# Перед вами словарь вида {слово: определение}, причём в определении всегда в начале есть гипероним (более общее слово или сочетание слов), отделённый запятой.
#
# Например:

# %%
dictionary = {'ДОМ': 'Здание, в котором живут',
              'КОФЕ': 'Напиток, который делают из кофейных зерен',
              'ШКОЛА': 'Здание, где учатся',
              'КРОВАТЬ': 'Предмет мебели, который используют для лежания',
              'ЧАЙ': 'Напиток, настоянный на специально обработанных листьях',
              'БОЛЬНИЦА': 'Здание, где лечат'}

# %% [markdown]
# 1. Напишите **функцию `hypernym`**, которая принимает определение и выдаёт гипероним в нижнем регистре.
#
# Принимает, например: `'Напиток, который делают из кофейных зерен'`, выдаёт: `'напиток'`
#
# 2. Напишите код, который создаёт словарь со списками гипонимов (более частных слов) к более общим. Используйте фунцию из пункта 1. Приведите все слова к нижнему регистру.
#
# Для нашего примера:
#
# ```<python>
# entities = {'здание': ['дом', 'школа', 'больница'],
#             'напиток': ['кофе', 'чай'],
#             'предмет мебели': ['кровать']}
# ```

# %% [markdown]
# ### Пора на работу?
#
# На неделе с 27ого марта по 2 апреля директор решил устроить себе каникулы.
#
# Но в важные даты ему надо быть на месте.
#
# Секретарь вводит строки в систему вида: `совещания | 27.03, 30.03` (вид мероприятия | даты через запятую)
#
# Секретарь вводит пустую строку `''`, чтобы закончить ввод
#
# ```
# совещания | 27.03, 30.03
# экзамены | 27.03, 29.03, 30.03
# олимпиада | 30.03
# день открытых дверей | 02.03
#
# ```
#
# 1. Выведите через запятую даты, в которые директору надо быть на работе. (для нашего примера: `27.03, 29.03, 30.03, 02.03`) Порядок дней не важен.
# 2. В сколько дней он сможет отдохнуть? (для нашего примера: `3`)

# %% [markdown]
# ## Для 2 и 4 вариантов

# %% [markdown]
# ### Даты
#
# Напишите **функцию `unify_date`**, которая принимает строку с датой и приводит дату к единому формату.
# 1. Все следующие записи функция должна приводить к виду `'29.03.2023'`.
#
# ```
# 29.03.2023
# 29/03/2023
# 23-03-2023
# 29.03 2023
# ```
#
# 2. Все следующие записи функция тоже должна приводить к виду `'29.03.2023'`.
#
# ```
# 2023-03-29
# 2023.03.29
# 2023/03/29
# ```
# (мысль1: год - четырёхзначное число, мысль2: перевернуть список довольно просто с помощью срезов)

# %% [markdown]
# ### Библиотека 1
#
# В библиотеке хранятся книги.

# %%
# Пример словаря с книгами
library = {'География. 6 класс': {'grade': '6',
                               'number': 117,
                               'tags': ['география']},
           'География. 7 класс': {'grade': '7',
                               'number': 110,
                               'tags': ['география']},
           'Робинзон Крузо': {'grade': '5-11',
                            'number': 3,
                            'tags': ['география', 'приключения']},
           'Три мушкетёра': {'grade': '5-11',
                            'number': 5,
                            'tags': ['приключения', 'Франция']},
           'Путешествия Гулливера': {'grade': '5-9',
                                  'number': 8,
                                  'tags': ['приключения']}}

# %% [markdown]
# 1. Сколько всего книг в библиотеке?
# 2. Поменяйте у всех книг значение по ключу `'grade'`. Сейчас это строки. Сделайте их списками чисел: не `'6'`, а `[6]`, не `'5-9'`, а `[5, 6, 7, 8, 9]` (вам поможет `range()`)

# %% [markdown]
# ### Библиотека 2
# В библиотеку поступают запросы. Пользователь вводит строку вида `География. 7 класс | 27` (название книги | количество)
# А программа печатает:
# - `Да, возьмите`, если в библиотеке есть нужное количество
# - `У нас только X`, если в библиотеке только X книг (X - число)
# - `У нас нет такого`, если книг с таким названием совсем нет
#
# Ввод: `География. 7 класс | 27`
# Вывод: `Да, возьмите`
#
# Ввод: `Три мушкетёра | 6`
# Вывод: `У нас только 5`
#
# Ввод: `Котлован | 1`
# Вывод: `У нас нет такого`
